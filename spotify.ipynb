# %%
import os
import pandas as pd

# %%
songs = pd.read_csv('./spotify_songs/spotify_songs.csv')

# %%
songs.head(5)
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# yarrrml-parser -i rules.yml -o rules.rml.ttl
# java -jar /path/to/rmlmapper.jar -m rules.rml.ttl

# %%
songs.iloc[1,:]
# Out:
# track_id                             0r7CVbZTWZgbTCYdfa2P31
# track_name                  Memories - Dillon Francis Remix
# track_artist                                       Maroon 5
# track_popularity                                         67
# track_album_id                       63rPSO264uRjW1X5E6cWv6
# track_album_name            Memories (Dillon Francis Remix)
# track_album_release_date                         2019-12-13
# playlist_name                                     Pop Remix
# playlist_id                          37i9dQZF1DXcZDD7cfEKhW
# playlist_genre                                          pop
# playlist_subgenre                                 dance pop
# danceability                                          0.726
# energy                                                0.815
# key                                                      11
# loudness                                             -4.969
# mode                                                      1
# ...

# %%
songs.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
songs['playlist_name'].unique().shape
# Out:
# (449,)

# %%
songs['playlist_id'].unique().shape
# Out:
# (471,)

# %%
songs['track_artist'].unique().tolist()
# Out:
# ['Ed Sheeran',
#  'Maroon 5',
#  'Zara Larsson',
#  'The Chainsmokers',
#  'Lewis Capaldi',
#  'Katy Perry',
#  'Sam Feldt',
#  'Avicii',
#  'Shawn Mendes',
#  'Ellie Goulding',
#  'Loud Luxury',
#  'Martin Garrix',
#  'AJ Mitchell',
#  'David Guetta',
#  'Sam Smith',
#  'Steve Aoki',
#  'R3HAB',
#  'Marshmello',
#  'Ava Max',
#  'Nikki Vianna',
#  'Charlie Puth',
#  'Starley',
#  'James Arthur',
#  'MAX',
#  'ILLENIUM',
#  'Bazzi vs.',
#  'Charli XCX',
#  'Kygo',
#  'Armin van Buuren',
#  'Billie Eilish',
#  'Sia',
#  'Sean Paul',
#  'Estelle',
#  'Bastille',
#  'for KING & COUNTRY',
#  'Lil Nas X',
#  'Calvin Harris',
#  "Why Don't We",
#  'Olympis',
#  'DJ Snake',
#  'Smash Mouth',
#  'SHAED',
#  'Kaskade',
#  'GASHI',
#  'Khalid',
#  'Herve Pagez',
#  'Mark Ronson',
#  'Arlissa',
#  '5 Seconds of Summer',
#  'Gryffin',
#  'NOTD',
#  'Jonas Blue',
#  '3LAU',
#  'Jax Jones',
#  'Zedd',
#  'Mabel',
#  'A R I Z O N A',
#  'Alesso',
#  'ayokay',
#  'ARTY',
#  'Maggie Lindemann',
# ...

# %%
songs['track_name'].unique().tolist()
# Out:
# ["I Don't Care (with Justin Bieber) - Loud Luxury Remix",
#  'Memories - Dillon Francis Remix',
#  'All the Time - Don Diablo Remix',
#  'Call You Mine - Keanu Silva Remix',
#  'Someone You Loved - Future Humans Remix',
#  'Beautiful People (feat. Khalid) - Jack Wins Remix',
#  'Never Really Over - R3HAB Remix',
#  'Post Malone (feat. RANI) - GATTÜSO Remix',
#  'Tough Love - Tiësto Remix / Radio Edit',
#  "If I Can't Have You - Gryffin Remix",
#  'Cross Me (feat. Chance the Rapper & PnB Rock) - M-22 Remix',
#  'Hate Me - R3HAB Remix',
#  'Body On My',
#  'SOS - Laidback Luke Tribute Remix / Radio Edit',
#  'Summer Days (feat. Macklemore & Patrick Stump of Fall Out Boy) - Tiësto Remix',
#  'South of the Border (feat. Camila Cabello & Cardi B) - Andy Jarvis Remix',
#  'All My Friends - Eden Prince Remix',
#  'Say My Name (feat. Bebe Rexha & J Balvin) - Lucas & Steve Remix',
#  'Dancing With A Stranger (With Normani) - Cheat Codes Remix',
#  'Let It Be Me - Sondr Remix',
# ...

# %%
ar = pd.DataFrame(songs['track_artist'].unique(),columns=['artist_name']).reset_index()
ar.columns = ['artist_id','artist_name']
ar.to_csv('./spotify_songs/artists.csv',index=False)
#.to_csv('artists.csv')

# %%
pd.DataFrame(songs['track_artist'].unique(),columns=['artist_name']).to_csv('artists.csv')

# %%
[a for a in songs['track_artist'].unique().tolist() if a.contains('feat')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\WUT\WUT\23Z\KnowledgeGraphs\project\spotify.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/WUT/WUT/23Z/KnowledgeGraphs/project/spotify.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> [a for a in songs['track_artist'].unique().tolist() if a.contains('feat')]
#
# f:\WUT\WUT\23Z\KnowledgeGraphs\project\spotify.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/WUT/WUT/23Z/KnowledgeGraphs/project/spotify.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> [a for a in songs['track_artist'].unique().tolist() if a.contains('feat')]
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
[a for a in songs['track_artist'].unique().tolist() if 'feat' in a]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\WUT\WUT\23Z\KnowledgeGraphs\project\spotify.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/WUT/WUT/23Z/KnowledgeGraphs/project/spotify.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> [a for a in songs['track_artist'].unique().tolist() if 'feat' in a]
#
# f:\WUT\WUT\23Z\KnowledgeGraphs\project\spotify.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/WUT/WUT/23Z/KnowledgeGraphs/project/spotify.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> [a for a in songs['track_artist'].unique().tolist() if 'feat' in a]
#
# TypeError: argument of type 'float' is not iterable

# %%
# Out:
# ['playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre']

# %%
playlists = songs[[s for s in songs.columns if 'playlist_' in s]]

# %%
playlists
# Out:
#          playlist_name             playlist_id playlist_genre  \
# 0            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop
# 1            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop
# 2            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop
# 3            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop
# 4            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop
# ...                ...                     ...            ...
# 32828  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32829  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32830  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32831  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm
# 32832  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm
#
#                playlist_subgenre
# 0                      dance pop
# 1                      dance pop
# 2                      dance pop
# 3                      dance pop
# 4                      dance pop
# ...

# %%
plu1 = playlists.drop_duplicates()
plu1
# Out:
#                                            playlist_name  \
# 0                                              Pop Remix
# 70                                             Dance Pop
# 167                                           Dance Room
# 223                                               Cardio
# 272                                       Dance Pop Hits
# ...                                                  ...
# 32409  Fresh EDM | Progressive House | Electro House ...
# 32504  Festival Music 2019 - Warm Up Music (EDM, Big ...
# 32582  Underground Party | Hypnotic | Minimal | Acid ...
# 32674                         Trending EDM by Nik Cooper
# 32753                                    ♥ EDM LOVE 2020
#
#                   playlist_id playlist_genre          playlist_subgenre
# 0      37i9dQZF1DXcZDD7cfEKhW            pop                  dance pop
# 70     37i9dQZF1DWZQaaqNMbbXa            pop                  dance pop
# ...

# %%
plu1.drop_duplicates(subset=['playlist_id']).reset_index().iloc[:,1:].to_csv('./spotify_songs/playlists.csv',index=False)

# %%
plu1.drop_duplicates(subset=['playlist_id']).reset_index().iloc[:,1:].to_csv('playlists.csv')

# %%
plu1.value_counts(subset=['playlist_id'])
# Out:
# playlist_id
# 4JkkvMpVl4lSioqQjeAL0q    3
# 2CJsD3fcYJWcliEKnwmovU    2
# 37i9dQZF1DX4OjfOteYnH8    2
# 37i9dQZF1DWTHM4kX49UKs    2
# 3Ho3iO0iJykgEQNbjB2sic    2
#                          ..
# 37i9dQZF1DWTLxOkM7PwUb    1
# 37i9dQZF1DWTIuAboZgTMf    1
# 37i9dQZF1DWTGaQ84g8alz    1
# 37i9dQZF1DWTDafB3skWPN    1
# 7xWuNevFBmwnFEg6wzdCc7    1
# Name: count, Length: 471, dtype: int64

# %%
plu1[plu1['playlist_id'] == "4JkkvMpVl4lSioqQjeAL0q"]
# Out:
#                                         playlist_name             playlist_id  \
# 18295  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥  4JkkvMpVl4lSioqQjeAL0q
# 19703  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥  4JkkvMpVl4lSioqQjeAL0q
# 23755  2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥  4JkkvMpVl4lSioqQjeAL0q
#
#       playlist_genre playlist_subgenre
# 18295          latin         latin pop
# 19703          latin     latin hip hop
# 23755            r&b           hip pop

# %%
plu1['playlist_id'].unique().shape
# Out:
# (471,)

# %%
playlists['playlist_id'].unique().shape
# Out:
# (471,)

# %%
for pl_id in playlists['playlist_id'].unique():
